# %% [markdown]
# # DeltaColorClip_IQR WAVG
#
# Based on S. Allam's MagClip_Pandas.py code...
#
# Created:  2020.10.01 --updated Oct21,2020 --last update Oct27,2020, Nov11,2020

# %% [markdown]
# ## 1. Initial Setup...

# %%
import numpy as np
import pandas as pd
import glob
import math
import os

import matplotlib.pyplot as plt


# %matplotlib inline

# %%
cd /data/des40.a/data/dtucker/Y6A1_abscal/SynthMags/PETModels/PETModelsCombined/Y6A2CoaddSummary_WAVG
# Out:
# /data/des40.a/data/dtucker/Y6A1_abscal/SynthMags/PETModels/PETModelsCombined/Y6A2CoaddSummary_WAVG

# %%
# %ls -FlthrG ../../../CalSpec/test/
# Out:
# total 1.9G
# -rw-rw-r-- 1 dtucker 4.1K Mar 21  2019  qaPlots.bash
# -rw-rw-r-- 1 dtucker  647 Jul 11  2019  synthColorList_gaia_match.bash
# -rw-rw-r-- 1 dtucker  791 Jul 17  2019  y4a1_fgcm_stds_synthColorList_gaia_match.bash
# -rwxrwxr-x 1 dtucker 1.2K Jul 17  2019  getEBV_new.py*
# -rw-rw-r-- 1 dtucker 9.5K Jul 17  2019  qaPlots.y4a1.bash
# -rwxrwxr-x 1 dtucker 4.5K Jul 25  2019  uniqHealpixList.py*
# -rw-rw-r-- 1 dtucker  922 Oct 22  2019  y6a1_fgcm_stds_synthColorList_gaia_match.bash
# -rw-rw-r-- 1 dtucker 9.5K Oct 22  2019  qaPlots.y6a1.bash~
# -rw-rw-r-- 1 dtucker 8.1K Nov 11  2019  calc_abmag.non_des.bash
# -rw-rw-r-- 1 dtucker 4.1K Dec 12  2019  calc_abmag.bash~
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  109vir_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  109vir_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  10lac_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  10lac_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  16cygb_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  16cygb_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1732526_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1732526_stisnic_004.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1740346_stisnic_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1743045_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1743045_stisnic_004.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1757132_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1757132_stiswfc_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1802271_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1802271_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1805292_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1805292_stisnic_004.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1808347_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1808347_stiswfc_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1812095_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  1812095_stisnic_004.mag.csv
# -rw-rw-r-- 1 dtucker  236 Dec 12  2019  1812524_nic_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  18sco_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  18sco_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker  244 Dec 12  2019  2m003618_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker  244 Dec 12  2019  2m003618_stiswfcnic_002.mag.csv
# -rw-rw-r-- 1 dtucker  244 Dec 12  2019  2m055914_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  agk_81d266_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  agk_81d266_stisnic_006.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  alpha_lyr_004.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  alpha_lyr_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  alpha_lyr_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  alpha_lyr_stis_008.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  alpha_lyr_stis_009.mag.csv
# -rw-rw-r-- 1 dtucker   56 Dec 12  2019  bd02d3375_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   56 Dec 12  2019  bd02d3375_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   56 Dec 12  2019  bd02d3375_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  239 Dec 12  2019  bd11d3759_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd_17d4708_stisnic_006.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  bd21d0607_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  bd21d0607_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  bd21d0607_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  bd_25d4655_002.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd26d2606_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd26d2606_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd26d2606_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  bd_28d4211_005.mag.csv
# -rw-rw-r-- 1 dtucker  239 Dec 12  2019  bd_28d4211_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  bd_28d4211_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   57 Dec 12  2019  bd29d2091_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   57 Dec 12  2019  bd29d2091_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   57 Dec 12  2019  bd29d2091_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  bd_33d2642_004.mag.csv
# -rw-rw-r-- 1 dtucker  239 Dec 12  2019  bd_33d2642_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd54d1216_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd54d1216_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  bd54d1216_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   58 Dec 12  2019  bd60d1753_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   58 Dec 12  2019  bd60d1753_stiswfc_001.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  bd_75d325_005.mag.csv
# -rw-rw-r-- 1 dtucker  238 Dec 12  2019  bd_75d325_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker  239 Dec 12  2019  bd_75d325_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  c26202_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  c26202_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  delumi_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  delumi_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  eta1dor_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  eta1dor_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  etauma_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker  236 Dec 12  2019  etauma_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  etauma_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  233 Dec 12  2019  feige110_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  feige110_stisnic_006.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  feige110_stisnic_007.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  feige34_005.mag.csv
# -rw-rw-r-- 1 dtucker  237 Dec 12  2019  feige34_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  237 Dec 12  2019  feige34_stis_005.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  feige66_002.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  feige67_002.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  g191b2b_005.mag.csv
# -rw-rw-r-- 1 dtucker  236 Dec 12  2019  g191b2b_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  g191b2b_mod_010.mag.csv
# -rw-rw-r-- 1 dtucker  241 Dec 12  2019  g191b2b_stisfuse_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  g191b2b_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker  231 Dec 12  2019  g93_48_004.mag.csv
# -rw-rw-r-- 1 dtucker  230 Dec 12  2019  gd108_005.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  gd153_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  gd153_mod_010.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  gd153_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker  229 Dec 12  2019  gd50_004.mag.csv
# -rw-rw-r-- 1 dtucker  233 Dec 12  2019  gd71_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  gd71_mod_010.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  gd71_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  gj7541a_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker  236 Dec 12  2019  grw_70d5824_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  grw_70d5824_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd009051_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd009051_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd009051_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd031128_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd031128_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd031128_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd074000_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd074000_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd074000_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd101452_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd101452_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd106252_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd106252_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd111980_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd111980_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd111980_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd115169_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd115169_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd116405_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd116405_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd128998_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd128998_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd142331_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd142331_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd14943_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd14943_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd158485_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd158485_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd159222_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd159222_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd160617_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd160617_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd160617_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd163466_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd163466_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd165459_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd165459_stisnic_004.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd167060_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd167060_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd180609_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd180609_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd185975_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd185975_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd185975_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd200654_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd200654_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   55 Dec 12  2019  hd200654_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd205905_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd205905_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd209458_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd209458_stisnic_007.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd2811_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd2811_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd37725_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd37725_stiswfc_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd37962_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd37962_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd38949_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd38949_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd55677_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd55677_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker  237 Dec 12  2019  hd60753_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  hd93521_005.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd93521_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker  237 Dec 12  2019  hd93521_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  hd93521_stis_005.mag.csv
# -rw-rw-r-- 1 dtucker  236 Dec 12  2019  hs2027_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  228 Dec 12  2019  hz2_005.mag.csv
# -rw-rw-r-- 1 dtucker  229 Dec 12  2019  hz21_005.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  hz21_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  hz21_stis_005.mag.csv
# -rw-rw-r-- 1 dtucker  228 Dec 12  2019  hz4_004.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  hz43b_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  233 Dec 12  2019  hz43_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  hz43_mod_010.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  hz43_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  229 Dec 12  2019  hz44_005.mag.csv
# -rw-rw-r-- 1 dtucker  233 Dec 12  2019  hz44_fos_003.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  hz44_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  234 Dec 12  2019  hz44_stis_005.mag.csv
# -rw-rw-r-- 1 dtucker  233 Dec 12  2019  hz4_stis_005.mag.csv
# -rw-rw-r-- 1 dtucker  233 Dec 12  2019  hz4_stis_006.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  kf01t5_nic_003.mag.csv
# -rw-rw-r-- 1 dtucker  235 Dec 12  2019  kf06t1_nic_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  kf06t2_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  kf06t2_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  kf08t3_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  kf08t3_stisnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  ksi2ceti_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  ksi2ceti_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  lamlep_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  lamlep_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  230 Dec 12  2019  lb227_004.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  lds749b_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  lds749b_mod_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  lds749b_stisnic_006.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  ltt9491_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  mucol_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   54 Dec 12  2019  mucol_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  232 Dec 12  2019  ngc7293_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p041c_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p041c_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p041c_stisnic_007.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p177d_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p177d_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p177d_stisnic_007.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p330e_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p330e_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  p330e_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  sdss132811_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  sdss132811_stis_002.mag.csv
# -rw-rw-r-- 1 dtucker  241 Dec 12  2019  sdssj151421_stis_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  sf1615_001a_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  sf1615_001a_stisnic_007.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  sirius_mod_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  sirius_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  sirius_stis_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  sirius_stis_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  snap1_stisnic_006.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  snap2_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  snap2_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   66 Dec 12  2019  sun_mod_001.mag.csv
# -rw-rw-r-- 1 dtucker   66 Dec 12  2019  sun_reference_stis_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  vb8_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd0308_565_mod_003.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  wd0308_565_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  wd0320_539_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  wd0947_857_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker  240 Dec 12  2019  wd1026_453_stis_004.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd1057_719_mod_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd1057_719_stisnic_006.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd1327_083_stiswfc_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd1327_083_stiswfc_002.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd1657_343_mod_005.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd1657_343_stiswfcnic_001.mag.csv
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd2341_322_stiswfc_001.mag.csv
# -rw-rw-r-- 1 dtucker    0 Dec 12  2019  WDcovar_001.mag.csv.xxx
# -rw-rw-r-- 1 dtucker   60 Dec 12  2019  wd2341_322_stiswfc_002.mag.csv
# -rw-rw-r-- 1 dtucker  34K Dec 12  2019  calc_abmag.20191212.log
# -rw-rw-r-- 1 dtucker 4.1K Dec 17  2019  calc_abmag.bash
# -rw-rw-r-- 1 dtucker  17K Dec 17  2019  synthMagList.csv~
# -rw-rw-r-- 1 dtucker  23K Dec 17  2019  synthMagColorList.tmp.csv~
# -rw-rw-r-- 1 dtucker  14K Dec 17  2019  calc_abmag.20191217.log
# -rw-rw-r-- 1 dtucker 1.9G Dec 17  2019  topcat_session.20191217.fits
# -rw-rw-r-- 1 dtucker 4.1K Jan  6  2020  calc_abmag_wd0308stismod.bash~
# -rw-rw-r-- 1 dtucker 4.2K Jan  6  2020  calc_abmag_wd0308stismod.bash
# -rw-rw-r-- 1 dtucker   60 Jan  6  2020  wd0308_565_stismod_004.mag.csv
# -rwxrwxr-x 1 dtucker 4.5K Mar  2  2020  uniqHealpixList_CalSpec.py~*
# -rwxrwxr-x 1 dtucker 4.8K Mar  2  2020  uniqHealpixList_CalSpec.py*
# -rw-rw-r-- 1 dtucker 163K Mar  2  2020  uniqHealpixList_CalSpec.20200302.log
# -rw-rw-r-- 1 dtucker  680 Mar  2  2020  synthMagColorList_gaia_match.bash~
# -rw-rw-r-- 1 dtucker  274 Mar  2  2020  synthMagColorList_gaia_match.20200302.log
# -rw-rw-r-- 1 dtucker  134 Mar  2  2020  getEBV_new.20200302.log
# -rw-rw-r-- 1 dtucker  631 Mar  3  2020  runAll.bash~
# -rw-rw-r-- 1 dtucker 190K Mar  3  2020  synthMagColorList_gaia_match.test.csv
# -rw-rw-r-- 1 dtucker  274 Mar  3  2020  synthMagColorList_gaia_match.20200303.log
# -rw-rw-r-- 1 dtucker  680 Mar  3  2020  synthMagColorList_gaia_match.bash
# -rw-rw-r-- 1 dtucker  942 Mar  3  2020  y6a1_fgcm_stds_synthMagColorList_gaia_match.bash~
# -rw-rw-r-- 1 dtucker  936 Mar  3  2020  y6a1_fgcm_stds_synthMagColorList_gaia_match.bash
# -rw-rw-r-- 1 dtucker  349 Mar  3  2020  y6a1_fgcm_stds_synthMagColorList_gaia_match.20200303.log
# -rw-rw-r-- 1 dtucker  11K Mar  3  2020  qaPlots.y6a1.new.bash
# -rw-rw-r-- 1 dtucker  635 Mar  3  2020  runAll.bash
# -rw-rw-r-- 1 dtucker  17K Mar  3  2020  synthMagList.csv
# -rw-rw-r-- 1 dtucker  23K Mar  3  2020  synthMagColorList.tmp.csv
# -rw-rw-r-- 1 dtucker 9.4K Mar  3  2020  objShortNameLUT.tmp1.csv
# -rw-rw-r-- 1 dtucker 111K Mar  3  2020  gaia_match.csv
# -rw-rw-r-- 1 dtucker 190K Mar  3  2020  synthMagColorList_gaia_match.csv
# -rw-rw-r-- 1 dtucker 189K Mar  3  2020  synthMagColorList_gaia_match_ebv.csv
# -rw-rw-r-- 1 dtucker 196K Mar  3  2020  Y6A1_FGCM_V2_1_2_2_ALL_STARS.full_match.new.mag_color.csv
# -rw-rw-r-- 1 dtucker  14K Mar  3  2020  qaPlot.dgr_vs_gi.y6a1_new.png
# -rw-rw-r-- 1 dtucker  14K Mar  3  2020  qaPlot.dri_vs_gi.y6a1_new.png
# -rw-rw-r-- 1 dtucker  14K Mar  3  2020  qaPlot.diz_vs_gi.y6a1_new.png
# -rw-rw-r-- 1 dtucker  14K Mar  3  2020  qaPlot.dzY_vs_gi.y6a1_new.png
# -rw-rw-r-- 1 dtucker  11K Mar  3  2020  qaPlot.dgr_vs_radec.y6a1_new.png
# -rw-rw-r-- 1 dtucker  12K Mar  3  2020  qaPlot.dgr_vs_radec.zoomed.y6a1_new.png
# -rw-rw-r-- 1 dtucker 178K Mar  3  2020  runAll.20200303.log
# -rw-rw-r-- 1 dtucker  936 Oct 11  2020  y6a1_fgcm_stds_synthMagColorList_gaia_match_psf.bash~
# -rw-rw-r-- 1 dtucker  940 Oct 11  2020  y6a1_fgcm_stds_synthMagColorList_gaia_match_psf.bash
# -rw-rw-r-- 1 dtucker  349 Oct 11  2020  y6a1_fgcm_stds_synthMagColorList_gaia_match_psf.20201011.log
# -rw-rw-r-- 1 dtucker 196K Oct 11  2020  Y6A1_FGCM_V3_3_1_PSF_ALL_STARS.full_match.new.mag_color.csv
# -rwxrwxr-x 1 dtucker 3.1K Nov  9  2020  y6a2CoaddSummaryMatch.py~*
# -rwxrwxr-x 1 dtucker 3.1K Nov  9  2020  y6a2CoaddSummaryMatch.py*
# -rw-rw-r-- 1 dtucker 501K Nov  9  2020  y6a2CoaddSummary_near_des_dawds.fits
# -rw-rw-r-- 1 dtucker 247K Nov  9  2020  y6a2CoaddSummary_match_best_36arcsec.combined.csv
# -rwxrwxr-x 1 dtucker 3.1K Nov 17  2020 '#y6a2CoaddSummaryMatch.py#'*

# %% [markdown]
# ## 2. Input Files...

# %%
# Input files for FGCM mag_psf solution...
inputFile='../ueberMasterList.1D_3D_MR.y6a2Coadd.csv'
inputFile_calspec = '../../../CalSpec/v2020-04-27/y6a2CoaddSummary_match_best_36arcsec.combined.csv'
inputFile_narayan = '../../../Narayan_G_2019_WDs/gnarayan-WDdata-b2daf1e/y6a2CoaddSummary_match_best_36arcsec.combined.des.csv'

#inputFile_calspec = '../../../CalSpec/test/Y6A1_FGCM_V3_3_1_PSF_ALL_STARS.full_match.new.mag_color.csv'
#inputFile_narayan = '../../../Narayan_G_2019_WDs/gnarayan-WDdata-b2daf1e/Y6A1_FGCM_V3_3_1_PSF_ALL_STARS.full_match.new.mag_color.des.csv'

# %% [markdown]
# ## 3.  Plotting Functions...

# %% [markdown]
# ### Histogram function...

# %%
def histPlotCompare3(data_df, data_df_clean, data_df_cleaner, column_x, title, xlabel, xlo, xhi, nbins):
    plt.hist( x=data_df[column_x], bins=nbins, range=(xlo,xhi), color='red', label='pre-cut')
    plt.hist( x=data_df_clean[column_x], bins=nbins, range=(xlo,xhi), color='yellow', label='stat. outlier' )
    plt.hist( x=data_df_cleaner[column_x], bins=nbins, range=(xlo,xhi), color='green', label='good' )
    plt.grid(True)
    plt.legend(loc='upper left')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Number')
    return 0

# %% [markdown]
# ### Main XY Plot Function...

# %%
def xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                   column_x, column_y, column_xerr, column_yerr, 
                   title, xlabel, ylabel, xlo, xhi, ylo, yhi, y_refvalue=0.00):
    plt.errorbar(data_df[column_x],data_df[column_y], \
                 xerr=data_df[column_xerr], yerr=data_df[column_yerr], \
                 fmt='.',color='red', ecolor='lightgray', elinewidth=3, capsize=0, label='pre-cut' )
    plt.errorbar(data_df_clean[column_x],data_df_clean[column_y], \
                 xerr=data_df_clean[column_xerr], yerr=data_df_clean[column_yerr], \
                 fmt='.',color='yellow', ecolor='yellow', elinewidth=3, capsize=0, label='stat. outlier' )
    plt.errorbar(data_df_cleaner[column_x],data_df_cleaner[column_y], \
                 xerr=data_df_cleaner[column_xerr], yerr=data_df_cleaner[column_yerr], \
                 fmt='.',color='green', ecolor='green', elinewidth=3, capsize=0, label='good' )
    plt.plot([xlo,xhi], [y_refvalue,y_refvalue], linestyle='dashed', label='mean')
    plt.xlim([xlo, xhi])
    plt.ylim([ylo, yhi])
    plt.grid(True)
    #plt.legend()
    plt.legend(loc='lower right')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    return 0

# %%
def xytPlot(data_df_cleaner, 
            column_x, column_y, column_xerr, column_yerr, column_teff, 
            title, xlabel, ylabel, xlo, xhi, ylo, yhi, y_refvalue=0.00):
    
    plt.scatter(data_df_cleaner[column_x],
                data_df_cleaner[column_y],
                c=data_df_cleaner[column_teff], 
                marker='o', 
                cmap='Vega20',
                label='good' 
               )

#cmap=plt.cm.get_cmap('Rainbow', 20),
#cmap='Vega20'
#plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))
#plt.colorbar()
#plt.clim(-1, 1);

        
    plt.clim(0., 40000.)

    # Add a colorbar
    cbar = plt.colorbar(label="Teff", orientation="horizontal")
    ##cbar.set_label('Teff', rotation=270, labelpad=15)
    ###cbar.ax.invert_yaxis()

    plt.errorbar(data_df_cleaner[column_x],
                 data_df_cleaner[column_y], 
                 xerr=data_df_cleaner[column_xerr], 
                 yerr=data_df_cleaner[column_yerr], 
                 fmt=None,
                 alpha=0.5, 
                 ecolor='gray', 
                 elinewidth=1, 
                 capsize=0, 
                 label=None)
    
    plt.plot([xlo,xhi], [y_refvalue,y_refvalue], linestyle='dashed', label='mean')
    
    plt.xlim([xlo, xhi])
    plt.ylim([ylo, yhi])
    plt.grid(True)
    
    plt.legend(loc='lower right')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    return 0

# %% [markdown]
# ### HST CalSpec XY Overplot Function...

# %%
def xyPlotOverplotCalSpec(calspec_df, column_x, column_y, column_xerr, column_yerr, ylo, yhi):
    
    plt.errorbar(calspec_df[column_x],calspec_df[column_y], \
                 xerr=calspec_df[column_xerr], yerr=calspec_df[column_yerr], \
                 fmt='.', color='blueviolet', ecolor='blueviolet', elinewidth=3, capsize=0, \
                 ms=15, label='HST CalSpec' )

    txt_array = calspec_df.objShortName.values
    x_array = calspec_df[column_x].values
    y_array = calspec_df[column_y].values
    #y2_array = np.full(len(txt_array), -0.07)
    
    for i, txt in enumerate(txt_array):
        
        yy = ylo + 0.20*(yhi-ylo)
        if txt == 'feige110':
            yy = yy + 0.05*(yhi-ylo)
    
        ax.annotate(txt, \
                    xy=(x_array[i], yy), \
                    color='blueviolet', ha='center')

        #ax.annotate(txt, \
        #            xy=(x_array[i], y_array[i]), \
        #            xytext=(x_array[i], y2_array[i]), \
        #            color='blueviolet', ha='center', \
        #            arrowprops=dict(arrowstyle="->", facecolor='blueviolet'))

       
        
    plt.legend(loc='lower right')

    return 0

# %% [markdown]
# ### Narayan et al. (2019) DA White Dwarf XY Overplot Function...

# %%
def xyPlotOverplotNarayan(narayan_df, column_x, column_y, column_xerr, column_yerr, ylo, yhi):
    
    plt.errorbar(narayan_df[column_x],narayan_df[column_y], \
                 xerr=narayan_df[column_xerr], yerr=narayan_df[column_yerr], \
                 fmt='.', color='deepskyblue', ecolor='deepskyblue', elinewidth=3, capsize=0, \
                 ms=15, label='Narayan et al. (2019)' )

    txt_array = narayan_df.objShortName.values
    x_array = narayan_df[column_x].values
    y_array = narayan_df[column_y].values
    y2_array = np.full(len(txt_array), -0.13)
    
    for i, txt in enumerate(txt_array):

        #yy = -0.12 + 0.02*(i%2)
        yy = ylo + 0.10*(yhi-ylo)
        yy = yy + 0.05*(yhi-ylo)*(i%2)

        ax.annotate(txt, \
                    xy=(x_array[i], yy), \
                    color='deepskyblue', ha='center')

        #ax.annotate(txt, \
        #            xy=(x_array[i], y_array[i]), \
        #            xytext=(x_array[i], y2_array[i]), \
        #            color='deepskyblue', ha='center', \
        #            arrowprops=dict(arrowstyle="->", facecolor='deepskyblue'))

       
        
    plt.legend(loc='lower right')

    return 0

# %% [markdown]
# ## 4. Read in  main input file...

# %%
data_df = pd.read_csv(inputFile)
data_df.head(5)
# Out:
#   set_obsRun_objShortName model_set  model_dimen  preferred_model_dimen  \
# 0   1_???_SSSJ013843-8325         1            1                      1
# 1   1_???_SSSJ033904-4037         1            1                      1
# 2   1_???_SSSJ040532-5055         1            1                      1
# 3   1_???_SSSJ041250-4510         1            1                      0
# 4   1_???_SSSJ043704-5728         1            1                      1
#
#   dirname                        filename     Teff    errT   logg   errg  \
# 0     NaN  spSpec-SSSJ013843-8325.ms.fits  32387.0  1935.0  6.056  0.401
# 1     NaN  spSpec-SSSJ033904-4037.ms.fits  29043.0  1563.0  6.536  0.289
# 2     NaN  spSpec-SSSJ040532-5055.ms.fits  18798.0  1634.0  7.692  0.283
# 3     NaN  spSpec-SSSJ041250-4510.ms.fits  12615.0   601.0  8.033  0.167
# 4     NaN  spSpec-SSSJ043704-5728.ms.fits  18519.0   846.0  8.145  0.146
#
#      ...     WAVG_SPREADERR_MODEL_Y WAVG_SPREAD_MODEL_Y FLAGS_Y  \
# 0    ...                        NaN                 NaN     NaN
# 1    ...                   0.000044           -0.000103     0.0
# 2    ...                   0.001515           -0.000482     0.0
# 3    ...                   0.000040           -0.000528     0.0
# 4    ...                   0.000065           -0.000147     2.0
#
#   IMAFLAGS_ISO_Y NEPOCHS_Y MOLY_NUMBER_Y sep_arcsec_coadd  SFD98_EBV_max  \
# 0            NaN       NaN           NaN              NaN       0.144093
# 1            0.0       7.0  2.841749e+15         4.689819       0.011286
# 2            0.0      10.0  2.842110e+15        15.951593       0.013446
# 3            0.0       8.0  2.848821e+15         3.240292       0.022683
# 4            0.0       7.0  2.849070e+15         1.749972       0.010637
#
#    R_sun_thick R_sun_thin
# 0          NaN        NaN
# 1          NaN        NaN
# 2     0.016107   0.015668
# 3     0.012616   0.012402
# 4     0.011775   0.011575
#
# [5 rows x 338 columns]

# %% [markdown]
# ### Calculate observed FGCM colors from observed FGCM magnitudes...

# %%
data_df['gr_std'] = (data_df['WAVG_MAG_PSF_G'] - data_df['WAVG_MAG_PSF_R'])
data_df['ri_std'] = (data_df['WAVG_MAG_PSF_R'] - data_df['WAVG_MAG_PSF_I'])
data_df['iz_std'] = (data_df['WAVG_MAG_PSF_I'] - data_df['WAVG_MAG_PSF_Z'])
data_df['zY_std'] = (data_df['WAVG_MAG_PSF_Z'] - data_df['WAVG_MAG_PSF_Y'])

data_df['gi_std'] = (data_df['WAVG_MAG_PSF_G'] - data_df['WAVG_MAG_PSF_I'])

# %% [markdown]
# ### Calculate statistical errrors for the observed FGCM colors...

# %%
#Assuming 0.1 err for Y-band

data_df['WAVG-MAGERR_PSF_Y']=.1



data_df['gr_std_err']=np.sqrt(data_df['WAVG_MAGERR_PSF_G']*data_df['WAVG_MAGERR_PSF_G'] + \
                              data_df['WAVG_MAGERR_PSF_R']*data_df['WAVG_MAGERR_PSF_R'] )
data_df['ri_std_err']=np.sqrt(data_df['WAVG_MAGERR_PSF_R']*data_df['WAVG_MAGERR_PSF_R'] + \
                              data_df['WAVG_MAGERR_PSF_I']*data_df['WAVG_MAGERR_PSF_I'] )
data_df['iz_std_err']=np.sqrt(data_df['WAVG_MAGERR_PSF_I']*data_df['WAVG_MAGERR_PSF_I'] + \
                              data_df['WAVG_MAGERR_PSF_Z']*data_df['WAVG_MAGERR_PSF_Z'] )
data_df['zY_std_err']=np.sqrt(data_df['WAVG_MAGERR_PSF_Z']*data_df['WAVG_MAGERR_PSF_Z'] + \
                              data_df['WAVG-MAGERR_PSF_Y']*data_df['WAVG_MAGERR_PSF_Y'] )

data_df['gi_std_err']=np.sqrt(data_df['WAVG_MAGERR_PSF_G']*data_df['WAVG_MAGERR_PSF_G'] + \
                              data_df['WAVG_MAGERR_PSF_I']*data_df['WAVG_MAGERR_PSF_I'] )

# %% [markdown]
# ### Calculate difference between the observed FGCM colors and the DES AB synthetic colors...

# %%
data_df['delta_STD_gr'] = data_df['gr_std'] - data_df['gr_1']
data_df['delta_STD_ri'] = data_df['ri_std'] - data_df['ri_1']
data_df['delta_STD_iz'] = data_df['iz_std'] - data_df['iz_1']
data_df['delta_STD_zY'] = data_df['zY_std'] - data_df['zY_1']

# %% [markdown]
# ### Calculate DES AB synthetic (g-i) colors for best-fit model ("gi_1") and the +/-errT, +/-errlogg models...

# %%
data_df['gi_1'] = ( data_df['gr_1'] + data_df['ri_1'] )
data_df['gi_2'] = ( data_df['gr_2'] + data_df['ri_2'] )
data_df['gi_3'] = ( data_df['gr_3'] + data_df['ri_3'] )
data_df['gi_4'] = ( data_df['gr_4'] + data_df['ri_4'] )
data_df['gi_5'] = ( data_df['gr_5'] + data_df['ri_5'] )

# %% [markdown]
# ### Calculate the average error in the DES AB synthetic colors based on the +/-errT, +/-errlogg model colors...

# %%
data_df['avgerr_gr'] = ( np.abs(data_df['gr_2']-data_df['gr_1']) \
                       + np.abs(data_df['gr_3']-data_df['gr_1']) \
                       + np.abs(data_df['gr_4']-data_df['gr_1']) \
                       + np.abs(data_df['gr_5']-data_df['gr_1']) )/4.0

data_df['avgerr_ri'] = ( np.abs(data_df['ri_2']-data_df['ri_1']) \
                       + np.abs(data_df['ri_3']-data_df['ri_1']) \
                       + np.abs(data_df['ri_4']-data_df['ri_1']) \
                       + np.abs(data_df['ri_5']-data_df['ri_1']) )/4.0

data_df['avgerr_iz'] = ( np.abs(data_df['iz_2']-data_df['iz_1']) \
                       + np.abs(data_df['iz_3']-data_df['iz_1']) \
                       + np.abs(data_df['iz_4']-data_df['iz_1']) \
                       + np.abs(data_df['iz_5']-data_df['iz_1']) )/4.0

data_df['avgerr_zY'] = ( np.abs(data_df['zY_2']-data_df['zY_1']) \
                       + np.abs(data_df['zY_3']-data_df['zY_1']) \
                       + np.abs(data_df['zY_4']-data_df['zY_1']) \
                       + np.abs(data_df['zY_5']-data_df['zY_1']) )/4.0


data_df['avgerr_gi'] = ( np.abs(data_df['gi_2']-data_df['gi_1']) \
                       + np.abs(data_df['gi_3']-data_df['gi_1']) \
                       + np.abs(data_df['gi_4']-data_df['gi_1']) \
                       + np.abs(data_df['gi_5']-data_df['gi_1']) )/4.0

# %% [markdown]
# ### Estimate the rms statistical error for the (FGCM - Synthetic) colors...

# %%
data_df['Err_STD_gr'] = np.sqrt(data_df['WAVG_MAGERR_PSF_G']*data_df['WAVG_MAGERR_PSF_G'] + \
                                data_df['WAVG_MAGERR_PSF_R']*data_df['WAVG_MAGERR_PSF_R'] + \
                                data_df['avgerr_gr']*data_df['avgerr_gr'])

data_df['Err_STD_ri'] = np.sqrt(data_df['WAVG_MAGERR_PSF_R']*data_df['WAVG_MAGERR_PSF_R'] + \
                                data_df['WAVG_MAGERR_PSF_I']*data_df['WAVG_MAGERR_PSF_I'] + \
                                data_df['avgerr_ri']*data_df['avgerr_ri'])

data_df['Err_STD_iz'] = np.sqrt(data_df['WAVG_MAGERR_PSF_I']*data_df['WAVG_MAGERR_PSF_I'] + \
                                data_df['WAVG_MAGERR_PSF_Z']*data_df['WAVG_MAGERR_PSF_Z'] + \
                                data_df['avgerr_iz']*data_df['avgerr_iz'])

data_df['Err_STD_zY'] = np.sqrt(data_df['WAVG_MAGERR_PSF_Z']*data_df['WAVG_MAGERR_PSF_Z'] + \
                                data_df['WAVG_MAGERR_PSF_Y']*data_df['WAVG_MAGERR_PSF_Y'] + \
                                data_df['avgerr_zY']*data_df['avgerr_zY'])

# %% [markdown]
# ## 5. Create masks to remove bad objects...

# %%
# DAWDs...
mask1 = data_df.comments_model.isnull()
data_df[mask1].MAG_APER_8_G.size
# Out:
# 294

# %%
# Good model...
mask2 = (data_df.errT/data_df.Teff < 0.1) & (data_df.errT < 1000.)
data_df[mask2].MAG_APER_8_G.size
# Out:
# 356

# %%
# Good astrometric matches (based on sanity check with Gaia DR2 colors)...
mask3 = ~( (data_df.MAG_APER_8_G-data_df.MAG_APER_8_R > 0.1) & (data_df.bp_rp < 0.245) )
data_df[mask3].MAG_APER_8_G.size
# Out:
# 455

# %%
# Gaia DR2 distances less than 300 pc...
mask4 = data_df.r_est < 300.
data_df[mask4].MAG_APER_8_G.size
# Out:
# 313

# %%
# Preferred model:  1D or 3D?...
mask5 = (data_df.preferred_model_dimen == 1)
data_df[mask5].MAG_APER_8_G.size
# Out:
# 430

# %%
# Combined masks...
mask = mask1 & mask2 & mask3 & mask4 & mask5
data_df[mask].MAG_APER_8_G.size
# Out:
# 213

# %%
data_df_clean = data_df[mask].copy()

# %%
data_df_clean
# Out:
#                           set_obsRun_objShortName model_set  model_dimen  \
# 4                           1_???_SSSJ043704-5728         1            1
# 5                           1_???_SSSJ063529-5920         1            1
# 7                           1_???_SSSJ105539-2919         1            1
# 8                           1_???_SSSJ122305-2932         1            1
# 9                           1_???_SSSJ131117-3025         1            1
# 10                             1_???_WDC0203-0459         1            1
# 11                             1_???_WDC0204-0459         1            1
# 15                             1_???_WDC0217-0653         1            1
# 25                             1_???_WDC0232-0512         1            1
# 26                             1_???_WDC0233-0715         1            1
# 27                             1_???_WDC0235-0609         1            1
# 30                             1_???_WDC0248p0004         1            1
# 31                             1_???_WDC0251-0057         1            1
# 35                             1_???_WDC0317p0124         1            1
# 36                             1_???_WDC0328-0759         1            1
# 37                             1_???_WDC0328-0040         1            1
# 41                             1_???_WDC0410-0409         1            1
# 42                             1_???_WDC0420p0036         1            1
# 43                             1_???_WDC0429-0448         1            1
# 44                             1_???_WDC0434-0035         1            1
# 47                           2/3_???_WDC0203-0459       2/3            1
# 50                           2/3_???_WDC0233-0715       2/3            1
# 51                           2/3_???_WDC0235-0609       2/3            1
# 54                           2/3_???_WDC0248p0004       2/3            1
# 55                           2/3_???_WDC0251-0057       2/3            1
# 60                           2/3_???_WDC0328-0759       2/3            1
# 61                           2/3_???_WDC0328-0040       2/3            1
# 66                           2/3_???_WDC0410-0409       2/3            1
# 67                           2/3_???_WDC0420p0036       2/3            1
# 69                           2/3_???_WDC0429-0448       2/3            1
# ..                                            ...       ...          ...
# 423  20190725_SepOct2018_GALEXJ231426.16-610010.9  20190725            1
# 424  20190725_SepOct2018_GALEXJ231455.29-543624.7  20190725            1
# 427  20190725_SepOct2018_GALEXJ234746.17-475341.6  20190725            1
# 430                     20200820_???_WDC0225-0456  20200820            3
# 431                  20200820_???_SSSJ041250-4510  20200820            3
# 432                  20200820_???_SSSJ071039-4144  20200820            3
# 433          20200820_Aug2017_SSSJ204645.7-525255  20200820            3
# 434                20200820_Dec2014_SSSJ0037-4821  20200820            3
# 435                20200820_Dec2014_SSSJ0041p0329  20200820            3
# 436                20200820_Dec2014_SSSJ0041-0226  20200820            3
# 437                20200820_Dec2014_SSSJ0057-4914  20200820            3
# 438                20200820_Dec2014_SSSJ0158-5632  20200820            3
# 439                20200820_Dec2014_SSSJ0237-5148  20200820            3
# 440                20200820_Dec2014_SSSJ0246-4209  20200820            3
# 441                20200820_Dec2014_SSSJ0329-4738  20200820            3
# 442                20200820_Dec2014_SSSJ0558-3556  20200820            3
# 443                20200820_Dec2014_SSSJ0710-4144  20200820            3
# 444          20200820_Feb2019_SSSJ055820.4-355653  20200820            3
# 445          20200820_Jan2018_SSSJ050640.2-551052  20200820            3
# 446          20200820_Jan2018_SSSJ055552.2-230152  20200820            3
# 447          20200820_Jan2018_SSSJ061046.7-500644  20200820            3
# 448          20200820_Jan2019_SSSJ024530.1-462406  20200820            3
# 449          20200820_Jan2019_SSSJ055820.4-355653  20200820            3
# 451        20200820_Oct2017_SSSJ20204645.7-525255  20200820            3
# 452          20200820_Oct2017_SSSJ205850.4-623913  20200820            3
# 453          20200820_Oct2017_SSSJ210400.1-481216  20200820            3
# 454         20200820_Oct2017_SSSJ2101220.2-441252  20200820            3
# 455          20200820_Oct2017_SSSJ214044.8-512413  20200820            3
# 456       20200820_SepOct2018_SSSJ222030.7-004105  20200820            3
# 457       20200820_SepOct2018_SSSJ225403.0-012241  20200820            3
#
#      preferred_model_dimen                   dirname  \
# 4                        1                       NaN
# 5                        1                       NaN
# 7                        1                       NaN
# 8                        1                       NaN
# 9                        1                       NaN
# 10                       1                       NaN
# 11                       1                       NaN
# 15                       1                       NaN
# 25                       1                       NaN
# 26                       1                       NaN
# 27                       1                       NaN
# 30                       1                       NaN
# 31                       1                       NaN
# 35                       1                       NaN
# 36                       1                       NaN
# 37                       1                       NaN
# 41                       1                       NaN
# 42                       1                       NaN
# 43                       1                       NaN
# 44                       1                       NaN
# 47                       1                       NaN
# 50                       1                       NaN
# 51                       1                       NaN
# 54                       1                       NaN
# 55                       1                       NaN
# 60                       1                       NaN
# 61                       1                       NaN
# 66                       1                       NaN
# 67                       1                       NaN
# 69                       1                       NaN
# ..                     ...                       ...
# 423                      1                       new
# 424                      1                       new
# 427                      1                       new
# 430                      1                       NaN
# 431                      1                       NaN
# 432                      1                       NaN
# 433                      1  SOAR4m_Aug2017_JMarriner
# 434                      1                       NaN
# 435                      1                       NaN
# 436                      1                       NaN
# 437                      1                       NaN
# 438                      1                       NaN
# 439                      1                       NaN
# 440                      1                       NaN
# 441                      1                       NaN
# 442                      1                       NaN
# 443                      1                       NaN
# 444                      1                       NaN
# 445                      1  SOAR4m_Jan2018_JMarriner
# 446                      1  SOAR4m_Jan2018_JMarriner
# 447                      1  SOAR4m_Jan2018_JMarriner
# 448                      1                       NaN
# 449                      1                       NaN
# 451                      1  SOAR4m_Oct2017_JMarriner
# 452                      1  SOAR4m_Oct2017_JMarriner
# 453                      1  SOAR4m_Oct2017_JMarriner
# 454                      1  SOAR4m_Oct2017_JMarriner
# 455                      1  SOAR4m_Oct2017_JMarriner
# 456                      1                       new
# 457                      1                       new
#
#                                filename     Teff   errT   logg   errg  \
# 4        spSpec-SSSJ043704-5728.ms.fits  18519.0  846.0  8.145  0.146
# 5        spSpec-SSSJ063529-5920.ms.fits  16459.0  462.0  8.015  0.086
# 7        spSpec-SSSJ105539-2919.ms.fits  16891.0  569.0  7.507  0.104
# 8        spSpec-SSSJ122305-2932.ms.fits  18736.0  783.0  8.139  0.134
# 9        spSpec-SSSJ131117-3025.ms.fits  16216.0  716.0  7.987  0.129
# 10   spSpec-WDC0203-0459_123b.spec.fits  25468.0  266.0  7.842  0.039
# 11   spSpec-WDC0204-0459_123b.spec.fits  26717.0  240.0  7.848  0.037
# 15   spSpec-WDC0217-0653_123b.spec.fits  14827.0  473.0  8.079  0.067
# 25    spSpec-WDC0232-0512_123.spec.fits  24297.0  637.0  8.076  0.091
# 26   spSpec-WDC0233-0715_123b.spec.fits  23651.0  115.0  7.932  0.016
# 27   spSpec-WDC0235-0609_123b.spec.fits  38456.0  446.0  7.953  0.053
# 30   spSpec-WDC0248p0004_123b.spec.fits  19033.0  148.0  8.097  0.025
# 31   spSpec-WDC0251-0057_123b.spec.fits  17435.0  262.0  7.982  0.048
# 35   spSpec-WDC0317p0124_123b.spec.fits  18020.0  282.0  8.019  0.050
# 36   spSpec-WDC0328-0759_123b.spec.fits  20991.0  395.0  7.861  0.057
# 37   spSpec-WDC0328-0040_123b.spec.fits  19238.0  825.0  7.807  0.137
# 41   spSpec-WDC0410-0409_123b.spec.fits  17389.0  162.0  8.004  0.030
# 42   spSpec-WDC0420p0036_123b.spec.fits  24655.0  294.0  8.013  0.042
# 43   spSpec-WDC0429-0448_123b.spec.fits  13825.0  259.0  8.449  0.041
# 44   spSpec-WDC0434-0035_123b.spec.fits  25825.0  408.0  8.065  0.061
# 47   spSpec-WDC0203-0459_comb.spec.fits  25975.0  331.0  7.718  0.048
# 50   spSpec-WDC0233-0715_comb.spec.fits  24062.0  189.0  7.845  0.026
# 51   spSpec-WDC0235-0609_comb.spec.fits  39551.0  638.0  7.782  0.073
# 54   spSpec-WDC0248p0004_comb.spec.fits  19594.0  227.0  8.014  0.036
# 55   spSpec-WDC0251-0057_comb.spec.fits  17849.0  283.0  7.933  0.052
# 60   spSpec-WDC0328-0759_comb.spec.fits  21503.0  452.0  7.796  0.063
# 61   spSpec-WDC0328-0040_comb.spec.fits  19965.0  938.0  7.650  0.148
# 66   spSpec-WDC0410-0409_comb.spec.fits  17792.0  191.0  7.927  0.035
# 67   spSpec-WDC0420p0036_comb.spec.fits  25079.0  301.0  7.937  0.043
# 69   spSpec-WDC0429-0448_comb.spec.fits  15037.0  255.0  8.093  0.040
# ..                                  ...      ...    ...    ...    ...
# 423                      obj955_sum.txt  19506.0  244.0  8.070  0.040
# 424                      obj956_sum.txt  19988.0  275.0  8.008  0.043
# 427                      obj971_sum.txt  29415.0  846.0  7.549  0.161
# 430  spSpec-WDC0225-0456_123b.spec.fits   9296.0   95.0  7.827  0.115
# 431      spSpec-SSSJ041250-4510.ms.fits  12967.0  601.0  7.790  0.167
# 432      spSpec-SSSJ071039-4144.ms.fits  12249.0  388.0  7.477  0.179
# 433         SSSJ204645.7-525255_sum.txt  11248.0  321.0  7.970  0.147
# 434               SSSJ0037-4821_sum.txt  10715.0   85.0  7.603  0.046
# 435               SSSJ0041p0329_sum.txt   9187.0   90.0  8.101  0.106
# 436               SSSJ0041-0226_sum.txt   7534.0  227.0  8.148  0.376
# 437               SSSJ0057-4914_sum.txt   9148.0   57.0  8.063  0.067
# 438               SSSJ0158-5632_sum.txt   8038.0   50.0  7.835  0.079
# 439               SSSJ0237-5148_sum.txt  10040.0   55.0  8.041  0.047
# 440               SSSJ0246-4209_sum.txt   8611.0  144.0  7.901  0.196
# 441               SSSJ0329-4738_sum.txt   9498.0   57.0  8.081  0.060
# 442               SSSJ0558-3556_sum.txt   7971.0   63.0  8.152  0.091
# 443               SSSJ0710-4144_sum.txt  12499.0  211.0  7.965  0.054
# 444                      obj254_sum.txt   7809.0   78.0  8.101  0.128
# 445         SSSJ050640.2-551052_sum.txt   9221.0   89.0  7.954  0.113
# 446         SSSJ055552.2-230152_sum.txt  10676.0  104.0  8.115  0.063
# 447         SSSJ061046.7-500644_sum.txt  10858.0  114.0  8.029  0.065
# 448                      obj139_sum.txt  12342.0  287.0  8.000  0.077
# 449                      obj254_sum.txt   7884.0   64.0  7.919  0.109
# 451       SSSJ20204645.7-525255_sum.txt  11507.0  194.0  8.065  0.067
# 452         SSSJ205850.4-623913_sum.txt  10844.0  120.0  8.076  0.065
# 453         SSSJ210400.1-481216_sum.txt   7930.0  245.0  7.872  0.423
# 454        SSSJ2101220.2-441252_sum.txt   9389.0  107.0  7.982  0.126
# 455         SSSJ214044.8-512413_sum.txt   7997.0  171.0  8.531  0.255
# 456                      obj297_sum.txt   7768.0  253.0  7.732  0.428
# 457                      obj306_sum.txt   7216.0  151.0  8.206  0.266
#
#        ...        gi_5 avgerr_gr avgerr_ri avgerr_iz avgerr_zY avgerr_gi  \
# 4      ...     -0.6844  0.012975  0.006375  0.003700  0.002125  0.019350
# 5      ...     -0.6419  0.009000  0.004425  0.002425  0.001350  0.013425
# 7      ...     -0.6739  0.009350  0.004725  0.003050  0.002000  0.014075
# 8      ...     -0.6909  0.011700  0.005775  0.003375  0.001950  0.017475
# 9      ...     -0.6298  0.014450  0.007100  0.003875  0.002125  0.021550
# 10     ...     -0.8268  0.002525  0.001300  0.000850  0.000475  0.003825
# 11     ...     -0.8445  0.002175  0.001075  0.000750  0.000425  0.003250
# 15     ...     -0.5772  0.012800  0.006525  0.003475  0.001475  0.019325
# 25     ...     -0.7991  0.006525  0.003225  0.002075  0.001200  0.009750
# 26     ...     -0.7990  0.001175  0.000600  0.000375  0.000200  0.001775
# 27     ...     -0.9325  0.001000  0.000425  0.000200  0.000100  0.001425
# 30     ...     -0.7094  0.002100  0.001050  0.000650  0.000350  0.003150
# 31     ...     -0.6747  0.004350  0.002200  0.001250  0.000700  0.006550
# 35     ...     -0.6873  0.004475  0.002150  0.001300  0.000750  0.006625
# 36     ...     -0.7525  0.004775  0.002325  0.001550  0.000925  0.007100
# 37     ...     -0.7138  0.011150  0.005600  0.003525  0.002250  0.016750
# 41     ...     -0.6743  0.002725  0.001350  0.000775  0.000450  0.004075
# 42     ...     -0.8103  0.002975  0.001425  0.001000  0.000525  0.004400
# 43     ...     -0.5108  0.007575  0.004025  0.001900  0.000650  0.011600
# 44     ...     -0.8252  0.003925  0.001950  0.001250  0.000725  0.005875
# 47     ...     -0.8360  0.003075  0.001525  0.001100  0.000625  0.004600
# 50     ...     -0.8067  0.001925  0.000925  0.000625  0.000425  0.002850
# 51     ...     -0.9371  0.001225  0.000575  0.000275  0.000125  0.001800
# 54     ...     -0.7230  0.003050  0.001525  0.000925  0.000600  0.004575
# 55     ...     -0.6867  0.004500  0.002225  0.001325  0.000800  0.006725
# 60     ...     -0.7628  0.005200  0.002600  0.001725  0.001050  0.007800
# 61     ...     -0.7317  0.011775  0.005900  0.003925  0.002550  0.017675
# 66     ...     -0.6870  0.003075  0.001500  0.000875  0.000550  0.004575
# 67     ...     -0.8184  0.002950  0.001475  0.000975  0.000550  0.004425
# 69     ...     -0.5926  0.006600  0.003325  0.001800  0.000800  0.009925
# ..     ...         ...       ...       ...       ...       ...       ...
# 423    ...     -0.7190  0.003350  0.001625  0.001025  0.000575  0.004975
# 424    ...     -0.7304  0.003600  0.001775  0.001100  0.000675  0.005375
# 427    ...     -0.8787  0.005850  0.002875  0.001900  0.001150  0.008725
# 430    ...     -0.1679  0.006975  0.004475  0.003700  0.001550  0.011450
# 431    ...     -0.4699  0.039075  0.019600  0.009675  0.003175  0.058675
# 432    ...     -0.4675  0.029025  0.013975  0.006650  0.003150  0.043000
# 433    ...     -0.3674  0.018725  0.011375  0.008025  0.002800  0.030100
# 434    ...     -0.3587  0.005325  0.003275  0.002300  0.000700  0.008600
# 435    ...     -0.1422  0.006825  0.004450  0.003625  0.001650  0.011275
# 436    ...      0.1480  0.027875  0.014850  0.010600  0.004675  0.042725
# 437    ...     -0.1410  0.004400  0.002850  0.002350  0.001050  0.007250
# 438    ...      0.0212  0.005100  0.002975  0.002225  0.001025  0.008075
# 439    ...     -0.2557  0.003625  0.002425  0.001975  0.000800  0.006050
# 440    ...     -0.0587  0.012850  0.007950  0.006250  0.002850  0.020800
# 441    ...     -0.1868  0.003900  0.002575  0.002125  0.000950  0.006475
# 442    ...      0.0389  0.005975  0.003425  0.002550  0.001150  0.009400
# 443    ...     -0.4670  0.012000  0.006275  0.003175  0.000950  0.018275
# 444    ...      0.0699  0.008775  0.004900  0.003600  0.001650  0.013675
# 445    ...     -0.1522  0.007025  0.004550  0.003750  0.001625  0.011575
# 446    ...     -0.3182  0.006650  0.004275  0.003375  0.001275  0.010925
# 447    ...     -0.3406  0.007525  0.004700  0.003600  0.001275  0.012225
# 448    ...     -0.4512  0.014850  0.008000  0.004375  0.001350  0.022850
# 449    ...      0.0518  0.007075  0.004025  0.002975  0.001375  0.011100
# 451    ...     -0.3961  0.008300  0.005000  0.003425  0.001225  0.013300
# 452    ...     -0.3366  0.007250  0.004575  0.003550  0.001300  0.011825
# 453    ...      0.0709  0.027275  0.015550  0.011475  0.005200  0.042825
# 454    ...     -0.1726  0.007950  0.005150  0.004350  0.001800  0.013100
# 455    ...      0.0593  0.019500  0.010925  0.008075  0.003650  0.030425
# 456    ...      0.0981  0.028250  0.015825  0.011525  0.005150  0.044075
# 457    ...      0.2007  0.020225  0.010325  0.007100  0.003075  0.030550
#
#     Err_STD_gr  Err_STD_ri  Err_STD_iz Err_STD_zY
# 4     0.012980    0.006389    0.003750   0.002738
# 5     0.009047    0.004541    0.002667   0.003391
# 7          NaN         NaN         NaN        NaN
# 8          NaN         NaN         NaN        NaN
# 9          NaN         NaN         NaN        NaN
# 10    0.002573    0.001440    0.001319   0.003528
# 11    0.002230    0.001241    0.001256   0.003521
# 15    0.012863    0.006706    0.004233   0.008197
# 25    0.006630    0.003660    0.003531   0.010891
# 26    0.001315    0.000873    0.000600   0.001061
# 27    0.001140    0.000820    0.001110   0.003284
# 30    0.002181    0.001299    0.001345   0.003383
# 31    0.004443    0.002486    0.002184   0.007651
# 35         NaN         NaN         NaN        NaN
# 36         NaN         NaN         NaN        NaN
# 37         NaN         NaN         NaN        NaN
# 41         NaN         NaN         NaN        NaN
# 42         NaN         NaN         NaN        NaN
# 43         NaN         NaN         NaN        NaN
# 44         NaN         NaN         NaN        NaN
# 47    0.003114    0.001646    0.001492   0.003551
# 50    0.002014    0.001121    0.000781   0.001125
# 51    0.001342    0.000906    0.001126   0.003285
# 54    0.003106    0.001706    0.001498   0.003418
# 55    0.004590    0.002508    0.002228   0.007661
# 60         NaN         NaN         NaN        NaN
# 61         NaN         NaN         NaN        NaN
# 66         NaN         NaN         NaN        NaN
# 67         NaN         NaN         NaN        NaN
# 69         NaN         NaN         NaN        NaN
# ..         ...         ...         ...        ...
# 423   0.003429    0.001887    0.001979   0.005971
# 424   0.003786    0.002319    0.002697   0.009207
# 427   0.005862    0.002912    0.002001   0.002180
# 430   0.007089    0.004693    0.004262   0.006602
# 431   0.039076    0.019604    0.009686   0.003344
# 432        NaN         NaN         NaN        NaN
# 433   0.018741    0.011415    0.008121   0.004992
# 434   0.005371    0.003366    0.002527   0.002421
# 435   0.006862    0.004519    0.003769   0.003393
# 436   0.027883    0.014865    0.010635   0.005471
# 437   0.004451    0.002935    0.002566   0.003242
# 438   0.005151    0.003070    0.002423   0.002334
# 439   0.003669    0.002568    0.002321   0.002831
# 440   0.012874    0.007993    0.006352   0.004069
# 441   0.003963    0.002697    0.002361   0.003363
# 442   0.006011    0.003489    0.002694   0.002774
# 443        NaN         NaN         NaN        NaN
# 444   0.008800    0.004945    0.003704   0.003016
# 445   0.007091    0.004674    0.004063   0.004492
# 446   0.006704    0.004377    0.003655   0.003951
# 447   0.007582    0.004791    0.003846   0.004586
# 448   0.014868    0.008044    0.004521   0.003496
# 449   0.007106    0.004080    0.003100   0.002874
# 451   0.008336    0.005091    0.003643   0.004310
# 452   0.007283    0.004645    0.003746   0.003665
# 453   0.027292    0.015593    0.011586   0.007282
# 454   0.008033    0.005291    0.004706   0.005963
# 455   0.019516    0.010955    0.008140   0.004679
# 456   0.028264    0.015856    0.011597   0.006520
# 457   0.020244    0.010364    0.007191   0.004347
#
# [213 rows x 367 columns]

# %% [markdown]
# ## 6. Read in HST CalSpec input file (for overplotting on DES DA WD results)...

# %%
calspec_df = pd.read_csv(inputFile_calspec)
mask1 = calspec_df.NEPOCHS_G.notnull()
mask2 = calspec_df.Separation < 5.0
mask3 = np.abs(calspec_df.WAVG_MAG_PSF_I - calspec_df.i) < 0.5
mask = mask1 & mask2 & mask3
calspec_df = calspec_df[mask].copy().reset_index(drop=True)

calspec_df['gr_std'] = (calspec_df['WAVG_MAG_PSF_G'] - calspec_df['WAVG_MAG_PSF_R'])
calspec_df['ri_std'] = (calspec_df['WAVG_MAG_PSF_R'] - calspec_df['WAVG_MAG_PSF_I'])
calspec_df['iz_std'] = (calspec_df['WAVG_MAG_PSF_I'] - calspec_df['WAVG_MAG_PSF_Z'])
calspec_df['zY_std'] = (calspec_df['WAVG_MAG_PSF_Z'] - calspec_df['WAVG_MAG_PSF_Y'])
calspec_df['gi_std'] = (calspec_df['WAVG_MAG_PSF_G'] - calspec_df['WAVG_MAG_PSF_I'])

calspec_df['gr_std_err']=np.sqrt(calspec_df['WAVG_MAGERR_PSF_G']*calspec_df['WAVG_MAGERR_PSF_G'] + \
                                 calspec_df['WAVG_MAGERR_PSF_R']*calspec_df['WAVG_MAGERR_PSF_R'] )
calspec_df['ri_std_err']=np.sqrt(calspec_df['WAVG_MAGERR_PSF_R']*calspec_df['WAVG_MAGERR_PSF_R'] + \
                                 calspec_df['WAVG_MAGERR_PSF_I']*calspec_df['WAVG_MAGERR_PSF_I'] )
calspec_df['iz_std_err']=np.sqrt(calspec_df['WAVG_MAGERR_PSF_I']*calspec_df['WAVG_MAGERR_PSF_I'] + \
                                 calspec_df['WAVG_MAGERR_PSF_Z']*calspec_df['WAVG_MAGERR_PSF_Z'] )
calspec_df['zY_std_err']=np.sqrt(calspec_df['WAVG_MAGERR_PSF_Z']*calspec_df['WAVG_MAGERR_PSF_Z'] + \
                                 calspec_df['WAVG_MAGERR_PSF_Y']*calspec_df['WAVG_MAGERR_PSF_Y'] )
calspec_df['gi_std_err']=np.sqrt(calspec_df['WAVG_MAGERR_PSF_G']*calspec_df['WAVG_MAGERR_PSF_G'] + \
                                 calspec_df['WAVG_MAGERR_PSF_I']*calspec_df['WAVG_MAGERR_PSF_I'] )

calspec_df['gi'] = ( calspec_df['gr'] + calspec_df['ri'] )

calspec_df['avgerr_gr'] = 0.0
calspec_df['avgerr_ri'] = 0.0
calspec_df['avgerr_iz'] = 0.0
calspec_df['avgerr_zY'] = 0.0
calspec_df['avgerr_gi'] = 0.0

calspec_df['delta_STD_gr'] = calspec_df['gr_std'] - calspec_df['gr']
calspec_df['delta_STD_ri'] = calspec_df['ri_std'] - calspec_df['ri']
calspec_df['delta_STD_iz'] = calspec_df['iz_std'] - calspec_df['iz']
calspec_df['delta_STD_zY'] = calspec_df['zY_std'] - calspec_df['zY']

calspec_df['Err_STD_gr'] = np.sqrt(calspec_df['WAVG_MAGERR_PSF_G']*calspec_df['WAVG_MAGERR_PSF_G'] + \
                                   calspec_df['WAVG_MAGERR_PSF_R']*calspec_df['WAVG_MAGERR_PSF_R'] + \
                                   calspec_df['avgerr_gr']*calspec_df['avgerr_gr'])

calspec_df['Err_STD_ri'] = np.sqrt(calspec_df['WAVG_MAGERR_PSF_R']*calspec_df['WAVG_MAGERR_PSF_R'] + \
                                   calspec_df['WAVG_MAGERR_PSF_I']*calspec_df['WAVG_MAGERR_PSF_I'] + \
                                   calspec_df['avgerr_ri']*calspec_df['avgerr_ri'])

calspec_df['Err_STD_iz'] = np.sqrt(calspec_df['WAVG_MAGERR_PSF_I']*calspec_df['WAVG_MAGERR_PSF_I'] + \
                                   calspec_df['WAVG_MAGERR_PSF_Z']*calspec_df['WAVG_MAGERR_PSF_Z'] + \
                                   calspec_df['avgerr_iz']*calspec_df['avgerr_iz'])

calspec_df['Err_STD_zY'] = np.sqrt(calspec_df['WAVG_MAGERR_PSF_Z']*calspec_df['WAVG_MAGERR_PSF_Z'] + \
                                   calspec_df['WAVG_MAGERR_PSF_Y']*calspec_df['WAVG_MAGERR_PSF_Y'] + \
                                   calspec_df['avgerr_zY']*calspec_df['avgerr_zY'])

calspec_df
#calspec_df[['objShortName','gr']]
# Out:
#   objShortName    StarName         RAHMS        DECDMS      RADEG     DECDEG  \
# 0       c26202      C26202  03:32:32.843  -27:51:48.58  53.136846 -27.863494
# 1       c26202      C26202  03:32:32.843  -27:51:48.58  53.136846 -27.863494
# 2   wd0320_539  WD0320-539  03:22:14.820  -53:45:16.47  50.561750 -53.754575
# 3   wd0320_539  WD0320-539  03:22:14.820  -53:45:16.47  50.561750 -53.754575
#
#   SpType      V       BV   SOLUTION_ID     ...     avgerr_zY  avgerr_gi  \
# 0   F8IV  16.64     0.26  1.635721e+18     ...           0.0        0.0
# 1   F8IV  16.64     0.26  1.635721e+18     ...           0.0        0.0
# 2     DA  14.90 -9999.00  1.635721e+18     ...           0.0        0.0
# 3     DA  14.90 -9999.00  1.635721e+18     ...           0.0        0.0
#
#    delta_STD_gr  delta_STD_ri  delta_STD_iz  delta_STD_zY  Err_STD_gr  \
# 0     -0.000298      0.002474      0.004052     -0.024816    0.000543
# 1      0.001002      0.003674      0.002952     -0.010016    0.000543
# 2      0.011792      0.008163      0.013242     -0.024196    0.000700
# 3      0.010192      0.008263      0.013242     -0.024196    0.000700
#
#    Err_STD_ri  Err_STD_iz  Err_STD_zY
# 0    0.000490    0.000554    0.001415
# 1    0.000490    0.000554    0.001415
# 2    0.000702    0.000511    0.001248
# 3    0.000702    0.000511    0.001248
#
# [4 rows x 336 columns]

# %% [markdown]
# ## 7. Read in Narayan et al. (2019) input file (for overplotting on DES DA WD results)...

# %%
narayan_df = pd.read_csv(inputFile_narayan)
mask1 = narayan_df.NEPOCHS_G.notnull()
mask2 = narayan_df.Separation < 5.0
mask3 = np.abs(narayan_df.WAVG_MAG_PSF_I - narayan_df.i) < 0.5
mask = mask1 & mask2 & mask3
narayan_df = narayan_df[mask].copy().reset_index(drop=True)

narayan_df['gr_std'] = (narayan_df['WAVG_MAG_PSF_G'] - narayan_df['WAVG_MAG_PSF_R'])
narayan_df['ri_std'] = (narayan_df['WAVG_MAG_PSF_R'] - narayan_df['WAVG_MAG_PSF_I'])
narayan_df['iz_std'] = (narayan_df['WAVG_MAG_PSF_I'] - narayan_df['WAVG_MAG_PSF_Z'])
narayan_df['zY_std'] = (narayan_df['WAVG_MAG_PSF_Z'] - narayan_df['WAVG_MAG_PSF_Y'])
narayan_df['gi_std'] = (narayan_df['WAVG_MAG_PSF_G'] - narayan_df['WAVG_MAG_PSF_I'])

narayan_df['gr_std_err']=np.sqrt(narayan_df['WAVG_MAGERR_PSF_G']*narayan_df['WAVG_MAGERR_PSF_G'] + \
                                 narayan_df['WAVG_MAGERR_PSF_R']*narayan_df['WAVG_MAGERR_PSF_R'] )
narayan_df['ri_std_err']=np.sqrt(narayan_df['WAVG_MAGERR_PSF_R']*narayan_df['WAVG_MAGERR_PSF_R'] + \
                                 narayan_df['WAVG_MAGERR_PSF_I']*narayan_df['WAVG_MAGERR_PSF_I'] )
narayan_df['iz_std_err']=np.sqrt(narayan_df['WAVG_MAGERR_PSF_I']*narayan_df['WAVG_MAGERR_PSF_I'] + \
                                 narayan_df['WAVG_MAGERR_PSF_Z']*narayan_df['WAVG_MAGERR_PSF_Z'] )
narayan_df['zY_std_err']=np.sqrt(narayan_df['WAVG_MAGERR_PSF_Z']*narayan_df['WAVG_MAGERR_PSF_Z'] + \
                                 narayan_df['WAVG_MAGERR_PSF_Y']*narayan_df['WAVG_MAGERR_PSF_Y'] )
narayan_df['gi_std_err']=np.sqrt(narayan_df['WAVG_MAGERR_PSF_G']*narayan_df['WAVG_MAGERR_PSF_G'] + \
                                 narayan_df['WAVG_MAGERR_PSF_I']*narayan_df['WAVG_MAGERR_PSF_I'] )

narayan_df['gi'] = ( narayan_df['gr'] + narayan_df['ri'] )

narayan_df['avgerr_gr'] = 0.0
narayan_df['avgerr_ri'] = 0.0
narayan_df['avgerr_iz'] = 0.0
narayan_df['avgerr_zY'] = 0.0
narayan_df['avgerr_gi'] = 0.0

narayan_df['delta_STD_gr'] = narayan_df['gr_std'] - narayan_df['gr']
narayan_df['delta_STD_ri'] = narayan_df['ri_std'] - narayan_df['ri']
narayan_df['delta_STD_iz'] = narayan_df['iz_std'] - narayan_df['iz']
narayan_df['delta_STD_zY'] = narayan_df['zY_std'] - narayan_df['zY']

narayan_df['Err_STD_gr'] = np.sqrt(narayan_df['WAVG_MAGERR_PSF_G']*narayan_df['WAVG_MAGERR_PSF_G'] + \
                                   narayan_df['WAVG_MAGERR_PSF_R']*narayan_df['WAVG_MAGERR_PSF_R'] + \
                                   narayan_df['avgerr_gr']*narayan_df['avgerr_gr'])

narayan_df['Err_STD_ri'] = np.sqrt(narayan_df['WAVG_MAGERR_PSF_R']*narayan_df['WAVG_MAGERR_PSF_R'] + \
                                   narayan_df['WAVG_MAGERR_PSF_I']*narayan_df['WAVG_MAGERR_PSF_I'] + \
                                   narayan_df['avgerr_ri']*narayan_df['avgerr_ri'])

narayan_df['Err_STD_iz'] = np.sqrt(narayan_df['WAVG_MAGERR_PSF_I']*narayan_df['WAVG_MAGERR_PSF_I'] + \
                                   narayan_df['WAVG_MAGERR_PSF_Z']*narayan_df['WAVG_MAGERR_PSF_Z'] + \
                                   narayan_df['avgerr_iz']*narayan_df['avgerr_iz'])

narayan_df['Err_STD_zY'] = np.sqrt(narayan_df['WAVG_MAGERR_PSF_Z']*narayan_df['WAVG_MAGERR_PSF_Z'] + \
                                   narayan_df['WAVG_MAGERR_PSF_Y']*narayan_df['WAVG_MAGERR_PSF_Y'] + \
                                   narayan_df['avgerr_zY']*narayan_df['avgerr_zY'])

narayan_df
#narayan_df[['objShortName','gr']]
# Out:
#   objShortName              objFullName         RAHMS         DECDMS  \
# 0  SDSSJ010322  SDSSJ010322.19-002047.7  01:03:22.191  -00:20:47.731
# 1  SDSSJ232941  SDSSJ232941.32+001107.8  23:29:41.325  +00:11:07.800
# 2  SDSSJ022817  SDSSJ022817.16-082716.4  02:28:17.169  -08:27:16.410
#
#         RADEG    DECDEG                 Comments   SOLUTION_ID  \
# 0   15.842462 -0.346592  epoch 2000.00; cycle 22  1.635721e+18
# 1  352.422188  0.185500  epoch 2000.00; cycle 22  1.635721e+18
# 2   37.071537 -8.454558  epoch 2000.00; cycle 22  1.635721e+18
#
#                     DESIGNATION     SOURCE_ID     ...      avgerr_zY  \
# 0  Gaia DR2 2536159496590552704  2.536159e+18     ...            0.0
# 1  Gaia DR2 2644572064644349952  2.644572e+18     ...            0.0
# 2  Gaia DR2 5176546064064586624  5.176546e+18     ...            0.0
#
#    avgerr_gi  delta_STD_gr  delta_STD_ri  delta_STD_iz  delta_STD_zY  \
# 0        0.0      0.000680      0.002873      0.008019      0.049165
# 1        0.0      0.007248     -0.003980      0.013744     -0.042737
# 2        0.0     -0.002198      0.009819     -0.010852     -0.045565
#
#    Err_STD_gr  Err_STD_ri  Err_STD_iz  Err_STD_zY
# 0    0.003545    0.005285    0.011383    0.049424
# 1    0.001610    0.002218    0.004081    0.015793
# 2    0.004297    0.006798    0.015018    0.074213
#
# [3 rows x 330 columns]

# %% [markdown]
# ## 8. Set up variables for analysis/plots...

# %%
inputFileBaseName = os.path.splitext(inputFile)[0]

colorName = ['gr', 
             'ri', 
             'iz', 
             'zY']

deltaColor = ['delta_STD_gr', 
              'delta_STD_ri', 
              'delta_STD_iz', 
              'delta_STD_zY']

errDeltaColor = ['Err_STD_gr', 
                 'Err_STD_ri',
                 'Err_STD_iz',
                 'Err_STD_zY']

clabel = ['FGCM (g-r)  -  Synth. (g-r)', 
          'FGCM (r-i)  -  Synth. (r-i)', 
          'FGCM (i-z)  -  Synth. (i-z)', 
          'FGCM (z-Y)  -  Synth. (z-Y)']
print(deltaColor)
# Out:
# ['delta_STD_gr', 'delta_STD_ri', 'delta_STD_iz', 'delta_STD_zY']

# %% [markdown]
# ## 9. Loop through the color indices, calculating the AB color offsets and plotting the  results...

# %%
for i in range(len(deltaColor)):

    print( "Hi") 
    print( deltaColor[i] )
    
    column_x = deltaColor[i]
    xlabel = clabel[i]
    
    # Calculate quartiles, inter-quartile range, and IQR outlier limits
    q1,q2,q3 = data_df_clean[column_x].quantile([.25, .5, .75])
    iqr = q3 - q1
    qlo = q1 - 1.5*iqr
    qhi = q3 + 1.5*iqr
    #print q1, q2, q3, iqr, qlo, qhi
    
    # Mask out data that fall outside the IQR outlier limits...
    mask = ( (data_df_clean[column_x] >= qlo) & (data_df_clean[column_x] <= qhi) )
    data_df_cleaner = data_df_clean[mask]
    
    # Output data_df_cleaner for this color...
    outputFile = """%s.%s.gold_sample.csv""" %(inputFileBaseName, colorName[i])
    print outputFile
    data_df_cleaner.to_csv(outputFile, index=False)

    
    # Calculate AB color offset statistics for this color index...
    nrows =   data_df_cleaner[column_x].size
    xmedian = np.median(data_df_cleaner[column_x])
    xmean =   np.mean(data_df_cleaner[column_x])
    xstd =    np.std(data_df_cleaner[column_x])
    xerr =    xstd/math.sqrt(nrows-1)
    print( """%d   %.4f   %.4f   %.4f   %.4f""" % ( nrows, xmedian, xmean, xstd, xerr ))
    
    
    title="""nstars=%d, median=%.4f, mean=%.4f, stddev=%.4f, stderr=%.4f""" % \
        ( nrows, xmedian, xmean, xstd, xerr )
    print(title)
    
    # Plot the histogram of results...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(10)
    status = histPlotCompare3(data_df, data_df_clean, data_df_cleaner, column_x, title, xlabel, -0.50, 0.50, 101)
    outputFile = """plot.%s.hist.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
    
    # Plot zoomed-in histogram of results...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(10)
    status = histPlotCompare3(data_df, data_df_clean, data_df_cleaner, column_x, title, xlabel, -0.15, 0.15, 41)
    outputFile = """plot.%s.hist_zoom.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
    
    # Plot delta_colors vs. Teff...
    column_x = 'Teff'
    column_xerr = 'errT'
    xlabel = 'Teff'

    column_y = deltaColor[i]
    column_yerr = errDeltaColor[i]
    ylabel = clabel[i]
    
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                       column_x, column_y, column_xerr, column_yerr, 
                       title, xlabel, ylabel, 5000., 40000., -0.50, +0.50, xmean)
    outputFile = """plot.%s.dcolor_vs_Teff.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
    
    # Plot delta_colors vs. Teff (zoomed-in)...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                       column_x, column_y, column_xerr, column_yerr, 
                       title, xlabel, ylabel, 5000., 40000., -0.15, +0.15, xmean)
    outputFile = """plot.%s.dcolor_vs_Teff_zoom.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)


    # Plot delta_colors vs. FGCM (g-i)...
    column_x = 'gi_std'
    column_xerr = 'gi_std_err'
    xlabel = 'FGCM (g-i)'

    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                       column_x, column_y, column_xerr, column_yerr, 
                       title, xlabel, ylabel, -1.1, 0.4, -0.50, +0.50, xmean)
    outputFile = """plot.%s.dcolor_vs_gi.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
 
    # Plot delta_colors vs. FGCM (g-i) (zoomed-in)...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                       column_x, column_y, column_xerr, column_yerr, 
                       title, xlabel, ylabel, -1.1, 0.4, -0.15, +0.15, xmean)
    outputFile = """plot.%s.dcolor_vs_gi_zoom.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
 
    # Plot delta_colors vs. FGCM (g-i), also overplotting results 
    # from HST CalSpec standards and Narayan et al. (2019) DAWDs...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                       column_x, column_y, column_xerr, column_yerr, 
                       title, xlabel, ylabel, -1.1, 1.1, -0.50, +0.50, xmean)
    status = xyPlotOverplotCalSpec(calspec_df, column_x, column_y, column_xerr, column_yerr, -0.50, +0.50)
    status = xyPlotOverplotNarayan(narayan_df, column_x, column_y, column_xerr, column_yerr, -0.50, +0.50)
    outputFile = """plot.%s.dcolor_vs_gi.calspec_narayan.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
 
    # Plot delta_colors vs. FGCM (g-i), also overplotting results 
    # from HST CalSpec standards and Narayan et al. (2019) DAWDs (zoomed-in)...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xyPlotCompare3(data_df, data_df_clean, data_df_cleaner, 
                       column_x, column_y, column_xerr, column_yerr, 
                       title, xlabel, ylabel, -1.1, 1.1, -0.15, +0.15, xmean)
    status = xyPlotOverplotCalSpec(calspec_df, column_x, column_y, column_xerr, column_yerr, -0.15, +0.15)
    status = xyPlotOverplotNarayan(narayan_df, column_x, column_y, column_xerr, column_yerr, -0.15, +0.15)
    outputFile = """plot.%s.dcolor_vs_gi_zoom.calspec_narayan.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
 
    # Plot just the "Golden Sample" for this color (zoomed in), 
    #  and color-code the symbols by Teff...
    fig, ax = plt.subplots()
    fig.set_figheight(5)
    fig.set_figwidth(20)
    status = xytPlot(data_df_cleaner, 
                     column_x, column_y, column_xerr, column_yerr, 'Teff',
                     title, xlabel, ylabel, -1.1, 1.1, -0.15, +0.15, xmean)
    outputFile = """plot.%s.dcolor_vs_gi_teff_zoom.%s.png""" %(inputFileBaseName, colorName[i])
    #plt.savefig(outputFile)
# Out:
# Hi
# delta_STD_gr
# ../ueberMasterList.1D_3D_MR.y6a2Coadd.gr.gold_sample.csv
# 149   0.0103   0.0109   0.0155   0.0013
# nstars=149, median=0.0103, mean=0.0109, stddev=0.0155, stderr=0.0013
# /usrdevel/dp0/dtucker/python_local/lib/python2.7/site-packages/numpy/lib/histograms.py:834: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usrdevel/dp0/dtucker/python_local/lib/python2.7/site-packages/numpy/lib/histograms.py:835: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des17a/lib/python2.7/site-packages/matplotlib/axes/_axes.py:2818: MatplotlibDeprecationWarning: Use of None object as fmt keyword argument to suppress plotting of data values is deprecated since 1.4; use the string "none" instead.
#   warnings.warn(msg, mplDeprecation, stacklevel=1)
# Hi
# delta_STD_ri
# ../ueberMasterList.1D_3D_MR.y6a2Coadd.ri.gold_sample.csv
# 146   0.0086   0.0091   0.0088   0.0007
# nstars=146, median=0.0086, mean=0.0091, stddev=0.0088, stderr=0.0007
# Hi
# delta_STD_iz
# ../ueberMasterList.1D_3D_MR.y6a2Coadd.iz.gold_sample.csv
# 153   0.0197   0.0201   0.0079   0.0006
# nstars=153, median=0.0197, mean=0.0201, stddev=0.0079, stderr=0.0006
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des17a/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Hi
# delta_STD_zY
# ../ueberMasterList.1D_3D_MR.y6a2Coadd.zY.gold_sample.csv
# 162   -0.0265   -0.0261   0.0080   0.0006
# nstars=162, median=-0.0265, mean=-0.0261, stddev=0.0080, stderr=0.0006

# %%
# %pwd
# Out:
# u'/data/des40.a/data/dtucker/Y6A1_abscal/SynthMags/PETModels/PETModelsCombined/Y6A2CoaddSummary_WAVG'
